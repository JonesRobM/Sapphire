# %%
from Sapphire.Post_Process import Process
# Define the environment variables for your analysis.

System = {
    'base_dir': '',
    'movie_file_name': 'movie.xyz',

    'Homo': ['Au', 'Pt'],

    'Hetero': False,

    'Start': 0, 'End': None, 'Step': 1, 'Skip': 1
}

# %%
# Define the quantities you want calculating given the names
# in the supporting documentation.

Quantities = {
    'Full':
    {
        'euc': None, 'rdf': None, 'pos': None,  'comdist': None,
        'moi': None, 'adj': None, 'pdf': None, 'pair_distance': None,
        'agcn': {'Write_Movie': False},
        'nn': None, 'com': None, 'cna_sigs': None,
        'cna_patterns': {'Write_Movie': True},
        'gyration': None, 'stat_radius': None,
        'surf_area': None, 'surf_atoms': None
    },

        'Energy':
    {
        'simtime': None, 'epot': None, 'etot': None,
        'ekin': None, 'edelta': None, 'meanetot': None, 'temp': None
    },

        'Homo':
    {
        'hopdf': None, 'hordf': None,
        'hocom': None, 'hoadj': None,
        'hocomdist': None, 'homidcomdist': None,
        'euc': None, 'hocna_sigs': None,
        'hocna_patterns': None, 'hogyration': None,
        'hosurf_area': None, 'hosurf_atoms': None,
        'hopair_distance': None
    },
        'Hetero':
    {
        'herdf': None, 'henn' :None,
        'headj': None, 'mix': None,
        'he_pair_distance': None,
        'homobonds': None,
        'heterobonds' : None,
        'elenn' : None,
        'lae' : None
    }
}

# %%
CNA_Pattern_Settings = {
    'npz_dir': 'CNA_npz/',  # folder to save the npz files in
    'new_xyz_dir': 'CNA_XYZs/',
    'APPEND_DICTIONARY': False,
    'FROM_MEMORY': False,
    'BULK_MASTERKEY': True,
    'SAVING_XYZ': True,
    'PRINTING_PATTERNS': True
}

# %%
Data = Process.Process(
    System=System, Quantities=Quantities,
    Pattern_Input=CNA_Pattern_Settings, Cores=6
)
# Out:
# /home/robert/Documents/Env/lib/python3.6/site-packages/Sapphire/Utilities/System_Clean.py:153: UserWarning:
# System property "extend_xyz" is bad. Typically, this is because the required information has not been provied by the user or is given incorrectly.
# Reverting to System default "None".
#
#   warnings.warn(none_template % ('extend_xyz', self.Default['extend_xyz']))
# /home/robert/Documents/Env/lib/python3.6/site-packages/Sapphire/Utilities/System_Clean.py:238: UserWarning:
# System property "End" is bad. Typically, this is because the required information has not been provied by the user or is given incorrectly.
# Reverting to System default "1000".
#
#   warnings.warn(none_template % ('End', self.Default['End']))
# /home/robert/Documents/Env/lib/python3.6/site-packages/Sapphire/Utilities/System_Clean.py:310: UserWarning:
# System property "UniformPDF" is bad. Typically, this is because the required information has not been provied by the user or is given incorrectly.
# Reverting to System default "False".
#
#   warnings.warn(none_template % ('UniformPDF', self.Default['UniformPDF']))
# /home/robert/Documents/Env/lib/python3.6/site-packages/Sapphire/Utilities/System_Clean.py:326: UserWarning:
# System property "Band" is bad. Typically, this is because the required information has not been provied by the user or is given incorrectly.
# Reverting to System default "0.05".
#
#   warnings.warn(none_template % ('Band', self.Default['Band']))
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
#
# Size of modified agcn is 147.
#
# Exception raised whilst computing the Surfce Area:
# list index out of range
# Compute Hetero dist for  HeAdj.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3c62f6c5e36d> in <module>
#       1 Data = Process.Process(
#       2     System=System, Quantities=Quantities,
# ----> 3     Pattern_Input=CNA_Pattern_Settings, Cores=6
#       4 )
#
# ~/Documents/Env/lib/python3.6/site-packages/Sapphire/Post_Process/Process.py in __init__(self, System, Quantities, Pattern_Input, Cores)
#      58         self.Initialising()
#      59         #self.run_pdf()
# ---> 60         self.run_core()
#      61
#      62     def ensure_dir(self, base_dir='', file_path=''):
#
# ~/Documents/Env/lib/python3.6/site-packages/Sapphire/Post_Process/Process.py in run_core(self)
#     642
#     643         for i in self.All_Times:
# --> 644             self.calculate(i)
#     645         with open(self.System.System['base_dir']+'Sapphire_Info.txt', "a") as f:
#     646             self.T3 = time.time()
#
# ~/Documents/Env/lib/python3.6/site-packages/Sapphire/Post_Process/Process.py in calculate(self, i)
#     292                                               Band = self.Band, Ele = x,
#     293                                               Type='Homo', Space = None,
# --> 294                                               System = self.System.System, Frame = i).ReturnRCut()
#     295                     except Exception as e:
#     296                         with open(self.Base + 'Sapphire_Errors.log', 'a') as f:
#
# ~/Documents/Env/lib/python3.6/site-packages/Sapphire/Post_Process/Kernels.py in __init__(self, Data, Band, Ele, Type, Space, System, Frame)
#      45         self.Data=np.array(self.Data)
#      46         self.Data = np.array([a for a in Data if a < 6.5])
# ---> 47         self.calculate()
#      48         self.write()
#      49
#
# ~/Documents/Env/lib/python3.6/site-packages/Sapphire/Post_Process/Kernels.py in calculate(self)
#     100
#     101         for i in range(len(self.Data)):
# --> 102             A.append(norm.pdf(self.Space, self.Data[i], self.Band))
#     103         self.Density = np.asarray(np.sum(A, axis=0))
#     104         self.Density = self.Density / np.trapz( self.Density, self.Space) #For normalisation purposes
#
# ~/Documents/Env/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1765         putmask(output, (1-cond0)+np.isnan(x), self.badvalue)
#    1766         if np.any(cond):
# -> 1767             goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#    1768             scale, goodargs = goodargs[-1], goodargs[:-1]
#    1769             place(output, cond, self._pdf(*goodargs) / scale)
#
# ~/Documents/Env/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in argsreduce(cond, *args)
#     532
#     533     """
# --> 534     newargs = np.atleast_1d(*args)
#     535     if not isinstance(newargs, list):
#     536         newargs = [newargs, ]
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# ~/Documents/Env/lib/python3.6/site-packages/numpy/core/shape_base.py in atleast_1d(*arys)
#      64     res = []
#      65     for ary in arys:
# ---> 66         ary = asanyarray(ary)
#      67         if ary.ndim == 0:
#      68             result = ary.reshape(1)
#
# ~/Documents/Env/lib/python3.6/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     134
#     135     """
# --> 136     return array(a, dtype, copy=False, order=order, subok=True)
#     137
#     138
#
# KeyboardInterrupt:
